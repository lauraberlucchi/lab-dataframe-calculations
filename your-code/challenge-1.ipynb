# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import data set.
#
# Read the dataset `pokemon.csv` into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import dataset
pokemon = pd.read_csv('pokemon.csv')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here
# extract values for type 1
dict_pokemon_1 = dict(pokemon['Type 1'].value_counts())
pokemon_type_1 = [type for type in dict_pokemon_1]
pokemon_type_1
# Out:
# ['Water',
#  'Normal',
#  'Grass',
#  'Bug',
#  'Psychic',
#  'Fire',
#  'Electric',
#  'Rock',
#  'Dragon',
#  'Ground',
#  'Ghost',
#  'Dark',
#  'Poison',
#  'Steel',
#  'Fighting',
#  'Ice',
#  'Fairy',
#  'Flying']

# %%
dict_pokemon_2 = dict(pokemon['Type 1'].value_counts())
pokemon_type_2 = [type for type in dict_pokemon_2]
pokemon_type_2
# Out:
# ['Water',
#  'Normal',
#  'Grass',
#  'Bug',
#  'Psychic',
#  'Fire',
#  'Electric',
#  'Rock',
#  'Dragon',
#  'Ground',
#  'Ghost',
#  'Dark',
#  'Poison',
#  'Steel',
#  'Fighting',
#  'Ice',
#  'Fairy',
#  'Flying']

# %%
distinct_pokemon_types = list(set(pokemon_type_1 + pokemon_type_2))
sorted(distinct_pokemon_types)
# I am not sure that I understood this part correctly. 
#I wanted to create two separate lists with types 1 and types 2 and create a distinct type list
#with unique elements across both list. Therefore, I call a set, where an element
#cannot be repeated. However, type 1 and type 2 have exactly the same values, and so does therefore the distinct pokemon list.
#I think I might have misunderstood, because I don't understand the point of the exercise.
# Out:
# ['Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water']

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
#value_counts gives too many values. no mapping method.
pokemon['Name']  = pokemon['Name'].apply(lambda name: name.replace('M',' M').split(' ', 1)[-1] if 'Mega' in name else name)
# test transformed data (first 10)
pokemon.head(20)
# Out:
#      #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3          Venusaur  Grass  Poison    525  80      82       83      100
# 3    3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4    4        Charmander   Fire     NaN    309  39      52       43       60
# 5    5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6    6         Charizard   Fire  Flying    534  78      84       78      109
# 7    6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8    6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9    7          Squirtle  Water     NaN    314  44      48       65       50
# 10   8         Wartortle  Water     NaN    405  59      63       80       65
# 11   9         Blastoise  Water     NaN    530  79      83      100       85
# 12   9    Mega Blastoise  Water     NaN    630  79     103      120      135
# 13  10          Caterpie    Bug     NaN    195  45      30       35       20
# 14  11           Metapod    Bug     NaN    205  50      20       55       25
# 15  12        Butterfree    Bug  Flying    395  60      45       50       90
# 16  13            Weedle    Bug  Poison    195  40      35       30       20
# 17  14            Kakuna    Bug  Poison    205  45      25       50       25
# 18  15          Beedrill    Bug  Poison    395  65      90       40       45
# 19  15     Mega Beedrill    Bug  Poison    495  65     150       40       15
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 4        50     65           1      False
# 5        65     80           1      False
# 6        85    100           1      False
# 7        85    100           1      False
# 8       115    100           1      False
# 9        64     43           1      False
# 10       80     58           1      False
# 11      105     78           1      False
# 12      115     78           1      False
# 13       20     45           1      False
# 14       25     30           1      False
# 15       80     70           1      False
# 16       20     50           1      False
# 17       25     35           1      False
# 18       80     75           1      False
# 19       80    145           1      False

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here
pokemon['A/D Ratio'] = round(pokemon['Attack']/pokemon['Defense'], 2)
pokemon.sample(10)
# Out:
#        #          Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 633  572      Minccino   Normal       NaN    300   55      50       40
# 42    37        Vulpix     Fire       NaN    299   38      41       40
# 425  384      Rayquaza   Dragon    Flying    680  105     150       90
# 116  108     Lickitung   Normal       NaN    385   90      55       75
# 723  655       Delphox     Fire   Psychic    534   75      69       72
# 443  398     Staraptor   Normal    Flying    485   85     120       70
# 75    69    Bellsprout    Grass    Poison    300   50      75       35
# 120  112        Rhydon   Ground      Rock    485  105     130      120
# 476  428  Mega Lopunny   Normal  Fighting    580   65     136       94
# 666  605        Elgyem  Psychic       NaN    335   55      55       55
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 633       40       40     75           5      False       1.25
# 42        50       65     65           1      False       1.02
# 425      150       90     95           3       True       1.67
# 116       60       75     30           1      False       0.73
# 723      114      100    104           6      False       0.96
# 443       50       60    100           4      False       1.71
# 75        70       30     40           1      False       2.14
# 120       45       45     40           1      False       1.08
# 476       54       96    135           4      False       1.45
# 666       85       55     30           5      False       1.00

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here
pokemon[pokemon['A/D Ratio'] == max(pokemon['A/D Ratio'])]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True        9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
pokemon[pokemon['A/D Ratio'] == min(pokemon['A/D Ratio'])]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  A/D Ratio
# 230      5           2      False       0.04

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# your code here    
pokemon['Combo Type'] =pokemon['Type 1'] + '-' + pokemon['Type 2']
pokemon['Combo Type'].fillna(pokemon['Type 1'], inplace=True)
pokemon.sample(10)
# Out:
#        #                   Name   Type 1    Type 2  Total  HP  Attack  \
# 131  122               Mr. Mime  Psychic     Fairy    460  40      45
# 566  507                Herdier   Normal       NaN    370  65      80
# 436  391               Monferno     Fire  Fighting    405  64      78
# 452  407               Roserade    Grass    Poison    515  60      70
# 225  209               Snubbull    Fairy       NaN    300  60      80
# 148  137                Porygon   Normal       NaN    395  65      60
# 529  477               Dusknoir    Ghost       NaN    525  45     100
# 542  485                Heatran     Fire     Steel    600  91      90
# 107   99                Kingler    Water       NaN    475  55     130
# 751  681  AegislashShield Forme    Steel     Ghost    520  60      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  \
# 131       65      100      120     90           1      False       0.69
# 566       65       35       65     60           5      False       1.23
# 436       52       78       52     81           4      False       1.50
# 452       65      125      105     90           4      False       1.08
# 225       50       40       40     30           2      False       1.60
# 148       70       85       75     40           1      False       0.86
# 529      135       65      135     45           4      False       0.74
# 542      106      130      106     77           4       True       0.85
# 107      115       50       50     75           1      False       1.13
# 751      150       50      150     60           6      False       0.33
#
#         Combo Type
# 131  Psychic-Fairy
# 566         Normal
# 436  Fire-Fighting
# 452   Grass-Poison
# 225          Fairy
# 148         Normal
# 529          Ghost
# 542     Fire-Steel
# 107          Water
# 751    Steel-Ghost

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here
pokemon_top_5 = pokemon.sort_values(by='A/D Ratio', ascending=False).head()
pokemon_top_5
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True       9.00     Psychic
# 347       65       20     65           3      False       4.50  Water-Dark
# 19        15       80    145           1      False       3.75  Bug-Poison
# 453       30       30     58           4      False       3.12        Rock
# 348       95       40     95           3      False       3.00  Water-Dark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here
dict(pokemon_top_5['Combo Type'].value_counts())
combo_type_list =  [type for type in dict(pokemon_top_5['Combo Type'].value_counts())]
combo_type_list
# Out:
# ['Water-Dark', 'Psychic', 'Bug-Poison', 'Rock']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
numeric_columns = pokemon.select_dtypes(include='number')
numeric_columns.columns
# Out:
# Index(['#', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed',
#        'Generation', 'A/D Ratio'],
#       dtype='object')

# %%
avg_combo_type = pokemon.groupby('Combo Type').agg({'#':'mean', 'Total':'mean', 'HP':'mean', 'Attack':'mean', 'Defense':'mean', 'Sp. Atk':'mean', 'Sp. Def':'mean',
 'Speed':'mean','Generation':'mean', 'A/D Ratio':'mean', 'HP':'mean'})
avg_combo_type
# Out:
#                         #       Total         HP      Attack     Defense  \
# Combo Type
# Bug            361.352941  289.705882  53.058824   50.352941   55.411765
# Bug-Electric   595.500000  395.500000  60.000000   62.000000   55.000000
# Bug-Fighting   214.000000  550.000000  80.000000  155.000000   95.000000
# Bug-Fire       636.500000  455.000000  70.000000   72.500000   60.000000
# Bug-Flying     286.285714  419.500000  63.000000   70.142857   61.571429
# ...                   ...         ...        ...         ...         ...
# Water-Ice      103.000000  511.666667  90.000000   83.333333  113.333333
# Water-Poison   118.666667  426.666667  61.666667   68.333333   58.333333
# Water-Psychic  111.800000  481.000000  87.000000   73.000000  104.000000
# Water-Rock     430.000000  428.750000  70.750000   82.750000  112.750000
# Water-Steel    395.000000  530.000000  84.000000   86.000000   88.000000
#
#                   Sp. Atk     Sp. Def      Speed  Generation  A/D Ratio
# Combo Type
# Bug             39.294118   43.647059  47.941176    3.470588   0.941176
# Bug-Electric    77.000000   55.000000  86.500000    5.000000   1.110000
# Bug-Fighting    40.000000  100.000000  80.000000    2.000000   1.640000
# Bug-Fire        92.500000   80.000000  80.000000    5.000000   1.235000
# Bug-Flying      72.857143   69.071429  82.857143    2.857143   1.145714
# ...                   ...         ...        ...         ...        ...
# Water-Ice       80.000000   78.333333  66.666667    1.000000   0.823333
# Water-Poison    61.666667   91.666667  85.000000    1.333333   1.163333
# Water-Psychic   94.000000   79.000000  44.000000    1.200000   0.784000
# Water-Rock      61.500000   65.000000  36.000000    3.750000   0.727500
# Water-Steel    111.000000  101.000000  60.000000    4.000000   0.980000
#
# [154 rows x 10 columns]

# %%
avg_combo_type = avg_combo_type.reset_index()
avg_combo_type
# Out:
#         Combo Type           #       Total         HP      Attack     Defense  \
# 0              Bug  361.352941  289.705882  53.058824   50.352941   55.411765
# 1     Bug-Electric  595.500000  395.500000  60.000000   62.000000   55.000000
# 2     Bug-Fighting  214.000000  550.000000  80.000000  155.000000   95.000000
# 3         Bug-Fire  636.500000  455.000000  70.000000   72.500000   60.000000
# 4       Bug-Flying  286.285714  419.500000  63.000000   70.142857   61.571429
# ..             ...         ...         ...        ...         ...         ...
# 149      Water-Ice  103.000000  511.666667  90.000000   83.333333  113.333333
# 150   Water-Poison  118.666667  426.666667  61.666667   68.333333   58.333333
# 151  Water-Psychic  111.800000  481.000000  87.000000   73.000000  104.000000
# 152     Water-Rock  430.000000  428.750000  70.750000   82.750000  112.750000
# 153    Water-Steel  395.000000  530.000000  84.000000   86.000000   88.000000
#
#         Sp. Atk     Sp. Def      Speed  Generation  A/D Ratio
# 0     39.294118   43.647059  47.941176    3.470588   0.941176
# 1     77.000000   55.000000  86.500000    5.000000   1.110000
# 2     40.000000  100.000000  80.000000    2.000000   1.640000
# 3     92.500000   80.000000  80.000000    5.000000   1.235000
# 4     72.857143   69.071429  82.857143    2.857143   1.145714
# ..          ...         ...        ...         ...        ...
# 149   80.000000   78.333333  66.666667    1.000000   0.823333
# 150   61.666667   91.666667  85.000000    1.333333   1.163333
# 151   94.000000   79.000000  44.000000    1.200000   0.784000
# 152   61.500000   65.000000  36.000000    3.750000   0.727500
# 153  111.000000  101.000000  60.000000    4.000000   0.980000
#
# [154 rows x 11 columns]

# %%
top_5_combo = avg_combo_type[avg_combo_type['Combo Type'].isin(combo_type_list)]
top_5_combo
# Out:
#      Combo Type           #       Total         HP      Attack     Defense  \
# 8    Bug-Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# 109     Psychic  381.973684  464.552632  72.552632   64.947368   67.236842
# 117        Rock  410.111111  409.444444  67.111111  103.333333  107.222222
# 140  Water-Dark  347.666667  493.833333  69.166667  120.000000   65.166667
#
#        Sp. Atk    Sp. Def      Speed  Generation  A/D Ratio
# 8    42.500000  59.333333  65.916667    2.333333   1.315833
# 109  98.552632  82.394737  78.868421    3.342105   1.164211
# 117  40.555556  58.333333  32.888889    3.888889   1.258889
# 140  88.833333  63.500000  87.166667    3.166667   2.291667

# %%
top_5_combo = top_5_combo.set_index('Combo Type')
top_5_combo
# Out:
#                      #       Total         HP      Attack     Defense  \
# Combo Type
# Bug-Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# Psychic     381.973684  464.552632  72.552632   64.947368   67.236842
# Rock        410.111111  409.444444  67.111111  103.333333  107.222222
# Water-Dark  347.666667  493.833333  69.166667  120.000000   65.166667
#
#               Sp. Atk    Sp. Def      Speed  Generation  A/D Ratio
# Combo Type
# Bug-Poison  42.500000  59.333333  65.916667    2.333333   1.315833
# Psychic     98.552632  82.394737  78.868421    3.342105   1.164211
# Rock        40.555556  58.333333  32.888889    3.888889   1.258889
# Water-Dark  88.833333  63.500000  87.166667    3.166667   2.291667
